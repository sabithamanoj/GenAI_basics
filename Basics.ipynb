# %% [markdown]
# <a href="https://colab.research.google.com/github/sabithamanoj/GenAI_basics/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative AI Notebook
#
# Author: Sabitha Manoj
# Course: IBM Generative AI Engineering
# Date:  12.03.2026
#
# Goal:
# Build and experiment with Generative AI models.

# %%
# Install required libraries

# !pip install transformers
# !pip install datasets
# !pip install langchain
# !pip install faiss-cpu
# !pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 64.4 MB/s eta 0:00:00
# ...
